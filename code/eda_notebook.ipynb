# %% [markdown]
# # EDA Notebook
# This runs the same EDA code as `main.py`.

# %%
from main import load_data, make_features, run_eda
data = load_data()
df = make_features(data)
run_eda(df)
